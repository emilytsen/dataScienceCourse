# %%
Participants = ['Carmen', 'Juan', 'Carlo', 'Violitta']
Participants
# Out:
# ['Carmen', 'Juan', 'Carlo', 'Violitta']

# %%
print (Participants[1])
#0, 1, 2, 3
# Out:
# Juan

# %%
#trás pra frente
#-4, -3, -2, -1
print (Participants[-1])
# Out:
# Violitta
